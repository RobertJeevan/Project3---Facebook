# %%
import numpy as np
import pandas as pd 
# %matplotlib notebook
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('C:\\Users\\Admin\\Desktop\\DS\\Project3 - facebook\\facebook.csv')

# %%
data
# Out:
#     Page total likes;Type;Category;Post Month;Post Weekday;Post Hour;Paid;Lifetime Post Total Reach;Lifetime Post Total Impressions;Lifetime Engaged Users;Lifetime Post Consumers;Lifetime Post Consumptions;Lifetime Post Impressions by people who have liked your Page;Lifetime Post reach by people who like your Page;Lifetime People who have liked your Page and engaged with your post;comment;like;share;Total Interactions
# 0    139441;Photo;2;12;4;3;0;2752;5091;178;109;159;...
# 1    139441;Status;2;12;3;10;0;10460;19057;1457;136...
# 2    139441;Photo;3;12;3;3;0;2413;4373;177;113;154;...
# 3    139441;Photo;2;12;2;10;1;50128;87991;2211;790;...
# 4    139441;Photo;2;12;2;3;0;7244;13594;671;410;580...
# 5    139441;Status;2;12;1;9;0;10472;20849;1191;1073...
# 6    139441;Photo;3;12;1;3;1;11692;19479;481;265;36...
# 7    139441;Photo;3;12;7;9;1;13720;24137;537;232;30...
# 8    139441;Status;2;12;7;3;0;11844;22538;1530;1407...
# 9    139441;Photo;3;12;6;10;0;4694;8668;280;183;250...
# ...

# %%
data.columns = ['new']

# %%
data.head()
# Out:
#                                                  new
# 0  139441;Photo;2;12;4;3;0;2752;5091;178;109;159;...
# 1  139441;Status;2;12;3;10;0;10460;19057;1457;136...
# 2  139441;Photo;3;12;3;3;0;2413;4373;177;113;154;...
# 3  139441;Photo;2;12;2;10;1;50128;87991;2211;790;...
# 4  139441;Photo;2;12;2;3;0;7244;13594;671;410;580...

# %%
data['Page_total_likes'] = data['new'].str.split(';').str[0]

# %%
data.head()
# Out:
#    Page_total_likes  Type  Category  Post_month  Post_weekday  Post_hour Paid  \
# 0            139441     1         2          12             4          3    0
# 1            139441     2         2          12             3         10    0
# 2            139441     1         3          12             3          3    0
# 3            139441     1         2          12             2         10    1
# 4            139441     1         2          12             2          3    0
#
#    Lifetime_post_total_reach  Lifetime_post_total_impressions  \
# 0                       2752                             5091
# 1                      10460                            19057
# 2                       2413                             4373
# 3                      50128                            87991
# 4                       7244                            13594
#
#    Lifetime_engaged_users  Lifetime_post_consumers  \
# 0                     178                      109
# ...

# %%
data.shape
# Out:
# (500, 19)

# %%
data['Type'] = data['new'].str.split(';').str[1]
data['Category'] = data['new'].str.split(';').str[2]
data['Post_month'] = data['new'].str.split(';').str[3]
data['Post_weekday'] = data['new'].str.split(';').str[4]
data['Post_hour'] = data['new'].str.split(';').str[5]
data['Paid'] = data['new'].str.split(';').str[6]

# %%
data['Lifetime_post_total_reach'] = data['new'].str.split(';').str[7]
data['Lifetime_post_total_impressions'] = data['new'].str.split(';').str[8]
data['Lifetime_engaged_users'] = data['new'].str.split(';').str[9]
data['Lifetime_post_consumers'] = data['new'].str.split(';').str[10]
data['Lifetime_post_consumptions'] = data['new'].str.split(';').str[11]
data['Post_impressions'] = data['new'].str.split(';').str[12]

# %%
data['Post_reach'] = data['new'].str.split(';').str[13]
data['Like_and_engaged'] = data['new'].str.split(';').str[14]
data['Comment'] = data['new'].str.split(';').str[15]
data['Likes'] = data['new'].str.split(';').str[16]
data['Share'] = data['new'].str.split(';').str[17]
data['Total_interactions'] = data['new'].str.split(';').str[18]

# %%
data.head()
# Out:
#                                                  new Page_total_likes    Type  \
# 0  139441;Photo;2;12;4;3;0;2752;5091;178;109;159;...           139441   Photo
# 1  139441;Status;2;12;3;10;0;10460;19057;1457;136...           139441  Status
# 2  139441;Photo;3;12;3;3;0;2413;4373;177;113;154;...           139441   Photo
# 3  139441;Photo;2;12;2;10;1;50128;87991;2211;790;...           139441   Photo
# 4  139441;Photo;2;12;2;3;0;7244;13594;671;410;580...           139441   Photo
#
#   Category Post_month Post_weekday Post_hour Paid Lifetime_post_total_reach  \
# 0        2         12            4         3    0                      2752
# 1        2         12            3        10    0                     10460
# 2        3         12            3         3    0                      2413
# 3        2         12            2        10    1                     50128
# 4        2         12            2         3    0                      7244
#
# ...

# %%
data.isnull().sum()
# Out:
# new                                0
# Page_total_likes                   0
# Type                               0
# Category                           0
# Post_month                         0
# Post_weekday                       0
# Post_hour                          0
# Paid                               0
# Lifetime_post_total_reach          0
# Lifetime_post_total_impressions    0
# Lifetime_engaged_users             0
# Lifetime_post_consumers            0
# Lifetime_post_consumptions         0
# Post_impressions                   0
# Post_reach                         0
# Like_and_engaged                   0
# Comment                            0
# Likes                              0
# Share                              0
# Total_interactions                 0
# dtype: int64

# %%
data = data.drop(['new'],axis = 1)

# %%
data.head()
# Out:
#   Page_total_likes    Type Category Post_month Post_weekday Post_hour Paid  \
# 0           139441   Photo        2         12            4         3    0
# 1           139441  Status        2         12            3        10    0
# 2           139441   Photo        3         12            3         3    0
# 3           139441   Photo        2         12            2        10    1
# 4           139441   Photo        2         12            2         3    0
#
#   Lifetime_post_total_reach Lifetime_post_total_impressions  \
# 0                      2752                            5091
# 1                     10460                           19057
# 2                      2413                            4373
# 3                     50128                           87991
# 4                      7244                           13594
#
#   Lifetime_engaged_users Lifetime_post_consumers Lifetime_post_consumptions  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
model = LabelEncoder()

# %%
 data.Type = model.fit_transform(data.Type)

# %%
data.head()
# Out:
#   Page_total_likes  Type Category Post_month Post_weekday Post_hour Paid  \
# 0           139441     1        2         12            4         3    0
# 1           139441     2        2         12            3        10    0
# 2           139441     1        3         12            3         3    0
# 3           139441     1        2         12            2        10    1
# 4           139441     1        2         12            2         3    0
#
#   Lifetime_post_total_reach Lifetime_post_total_impressions  \
# 0                      2752                            5091
# 1                     10460                           19057
# 2                      2413                            4373
# 3                     50128                           87991
# 4                      7244                           13594
#
#   Lifetime_engaged_users Lifetime_post_consumers Lifetime_post_consumptions  \
# 0                    178                     109                        159
# ...

# %%
data.describe()
# Out:
#              Type
# count  500.000000
# mean     1.074000
# std      0.429993
# min      0.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max      3.000000

# %%
data.columns
# Out:
# Index(['Page_total_likes', 'Type', 'Category', 'Post_month', 'Post_weekday',
#        'Post_hour', 'Paid', 'Lifetime_post_total_reach',
#        'Lifetime_post_total_impressions', 'Lifetime_engaged_users',
#        'Lifetime_post_consumers', 'Lifetime_post_consumptions',
#        'Post_impressions', 'Post_reach', 'Like_and_engaged', 'Comment',
#        'Likes', 'Share', 'Total_interactions'],
#       dtype='object')

# %%
data['Page_total_likes'] = data['Page_total_likes'].astype(int)
data['Type'] = data['Type'].astype(int)
data['Category'] = data['Category'].astype(int)
data['Post_month'] = data['Post_month'].astype(int)
data['Post_weekday'] = data['Post_weekday'].astype(int)

# %%
data['Post_hour'] = data['Post_hour'].astype(int)
data['Lifetime_post_total_reach'] = data['Lifetime_post_total_reach'].astype(int)
data['Lifetime_engaged_users'] = data['Lifetime_engaged_users'].astype(int)
data['Lifetime_post_consumers'] = data['Lifetime_post_consumers'].astype(int)
data['Lifetime_post_consumptions'] = data['Lifetime_post_consumptions'].astype(int)

# %%
data['Post_impressions'] = data['Post_impressions'].astype(int)
data['Post_reach'] = data['Post_reach'].astype(int)
data['Like_and_engaged'] = data['Like_and_engaged'].astype(int)
data['Comment'] = data['Comment'].astype(int)
data['Total_interactions'] = data['Total_interactions'].astype(int)
data['Lifetime_post_total_impressions'] = data['Lifetime_post_total_impressions'].astype(int)

# %%
## data['Likes'] = data['Likes'].astype(int)
## data['Share'] = data['Share'].astype(int)
## data['Paid'] = data['Paid'].astype(int)

# %%
sns.jointplot(x = 'Total_interactions',y= 'Page_total_likes',data=data,kind = 'scatter')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.jointplot(x= 'Page_total_likes',y = 'Total_interactions',data=data,kind = 'hex')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.jointplot(x = 'Total_interactions',y= 'Type',data=data,kind = 'reg')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.pairplot(data,hue = 'Type')
# Out:
# <img src="data:image/png;base64,..." width="4058">

# %%
sns.jointplot(x = 'Total_interactions',y = 'Post_month',data = data,kind = 'reg')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.jointplot(x = 'Total_interactions',y = 'Post_weekday',data = data,kind = 'reg')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.catplot(x = 'Total_interactions', y = 'Lifetime_post_consumers',data = data,hue ='Paid',kind = 'box')
# Out:
# <img src="data:image/png;base64,..." width="558">

# %%
data.Paid.isnull().sum()
# Out:
# 0

# %%
y = data.Total_interactions
x = data.iloc[:,[3,4,5,7,8,9,10,11,12,13,14,15]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.25 , random_state = 100)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predict = model.predict(x_test)

# %%
predict
# Out:
# array([ 125.14087816,  165.82602839,  169.51266135,   63.35990385,
#          78.13873915,  151.57941475,  215.33307483,  115.26378644,
#         161.0125539 ,   22.75435058,   28.90599544,  408.93148514,
#         714.56289274,   25.97746699,   64.87539087,   76.94432258,
#         239.82443952,  151.98951726,  415.36820603,  117.52271547,
#         368.90564195,   79.88216957,  136.86912302,  116.49172653,
#         240.83115252,  134.45279987,   22.53468788,  175.7720081 ,
#          96.51253144,   32.9210782 ,  217.60521822,   78.48573064,
#         132.42274552,   80.69835547, 1950.35844391,  145.57006124,
#          30.34596068,  125.47929345,  122.34200368,  281.9312371 ,
#          15.08943751,  127.91096967,   90.42411944,  346.5717684 ,
#         211.60253994,   47.52919911,  238.57746502,   25.32243076,
#         634.42527705, 1871.40881807,  301.77618918,  262.42185056,
#         100.80640686,   85.52355653,  264.14266868,   26.74901125,
# ...

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,predict)
# Out:
# 0.9657408530998088
